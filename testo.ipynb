# %%
# librerias

import numpy as np
import pandas as pd
import os
import sys

from sortedcontainers import SortedDict

import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
import regex as re
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/ambar/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
size_per_block = 10240*4 # 4 KBytes
num_block = 0
path_block = './blocks/'

# %%
class PostingBlock:
    def __init__(self, max_size = 7):
        self.docs = []
        self.next_block = None
        self.max_size = max_size

    def is_full(self):
        return len(self.docs) >= self.max_size

    def add_doc(self, doc_id, tf):
        self.docs.append((doc_id,tf))

# %%
def ParseDocs(doc):
    words = []

    col_text = ['lyrics', 'track_name', 'track_artist', 'track_album_name', 'playlist_name', 'playlist_genre', 'playlist_subgenre']
    texto = ''
    for col in col_text:
        texto += ' ' + doc[col]

    texto = texto.lower()

    texto = re.sub(r'[^a-zA-Z0-9_À-ÿ]', ' ', texto)


    if doc['language'] == 'es':
        ln = 'spanish'
    elif doc['language'] == 'tl':
        ln = 'english'
    else:
        ln = 'english'
    
    for word in texto.split():
        
        if word not in stopwords.words(ln):
            words.append(word)

    # aplicar stemming
    stemmer = SnowballStemmer(language=ln)
    words = [stemmer.stem(word) for word in words]

    return words

# %%
def WriteBlockToDisk(dictionary, block_id, path='./blocks/'):
    output_file = f"{path}block_{block_id}.txt"
    
    with open(output_file, 'w') as f:
        for term, data in dictionary.items():
            df = data['df']
            postings_list = []
            posting_block = data['posting_block']
            while posting_block is not None:
                postings_list.extend([f"({doc_id}, {tf})" for doc_id, tf in posting_block.docs])
                posting_block = posting_block.next_block
            postings = ', '.join(postings_list)
            f.write(f"{term} (DF: {df}): {postings}\n")
    
    print(f"Block {block_id} written to disk as {output_file}")

# %%
def SPIMI_INVERT(token_stream, # recibo una lista de lexemas
                 docId, # el numero del documento
                 num_block, # el numero del bloque en el que escribo
                 size_per_block,
                 path_block = './blocks/'
                 ):
    
    # name_block_archive = path_block + f'block_{num_block}.txt'
    # outputFile = open(name_block_archive, 'w') # NewFIle()

    global global_dictionary, global_block_size

    # dictionary = {} # NewHash() - Diccionario invertido parcial
    # block_size = 0

    
    for token in token_stream:

        if token not in global_dictionary:
            posting_block = PostingBlock()
            global_dictionary[token] = {
                'df': 1,
                'posting_block': posting_block
            }
            posting_block.add_doc(docId, 1)
            global_block_size += sys.getsizeof(token) + sys.getsizeof(global_dictionary[token])
            print(f'word nuevo: {token} se suma block_size: {global_block_size}')
        
        else:
            # posting_list = GetPostingsList(dictionary, term(token))
            posting_block = global_dictionary[token]['posting_block']
            
            doc_found = False
            while posting_block is not None:
                for idx, (doc, tf) in enumerate(posting_block.docs):
                    if doc == docId:
                        posting_block.docs[idx] = (doc, tf + 1)
                        doc_found = True
                        break
                
                if doc_found:
                    break
                
                if posting_block.next_block is None:
                    break
                else:
                    posting_block = posting_block.next_block

            # si el documento no existe    
            if not doc_found:
                global_dictionary[token]['df'] += 1
                
                if posting_block.is_full():
                    new_posting_block = PostingBlock()
                    posting_block.next_block = new_posting_block
                    posting_block = new_posting_block

                posting_block.add_doc(docId, 1)  # Añadir el nuevo doc_id con TF=1
                global_block_size += sys.getsizeof(docId)  # Sumar el tamaño de doc_id

        # Si el bloque alcanza el límite de tamaño, escribir a disco y resetear el diccionario
        if global_block_size >= size_per_block:
            print(f"Writing block {num_block} to disk (block size: {global_block_size} bytes)")
            WriteBlockToDisk(global_dictionary, num_block, path=path_block)
            global_dictionary = {}  # Reiniciar el diccionario global
            global_block_size = 0  # Reiniciar el tamaño del bloque
            num_block += 1  # Incrementar el número de bloque
    
    # sorted_terms = SortTerms(dictionary)
    # sorted_terms = SorTerms(dictionary)
    if global_dictionary:
        WriteBlockToDisk(global_dictionary, num_block, path=path_block)
    # WriteBlocksToDisk(sorted_terms, dictionary,outputFile)
    return num_block

# %%
def BSBIndexConstuction(data):

    block_n = 0 # numero de bloque actual 

    f = {} # archivos de bloques
    for doc_id, row  in data.iterrows():

        token_stream = ParseDocs(row)
        num_block = SPIMI_INVERT(token_stream, doc_id, num_block=block_n,  size_per_block=size_per_block, path_block=path_block,)
        block_n = num_block
        f[num_block] = f'{path_block}block_{num_block}.txt'
    
    # f = MergeBlocks(f) 
    return f

# %%
# testeo
path = './dataset/'
data_path = path + 'spotify_songs_test.csv'

global_dictionary = {}
global_block_size = 0

data = pd.read_csv(data_path)

# %%
BSBIndexConstuction(data)
# Out:
# word nuevo: minsan se suma block_size: 231
# word nuevo: pa se suma block_size: 458
# word nuevo: nang se suma block_size: 687
# word nuevo: ako se suma block_size: 915
# word nuevo: napalingon se suma block_size: 1150
# word nuevo: hindi se suma block_size: 1380
# word nuevo: ko se suma block_size: 1607
# word nuevo: alam se suma block_size: 1836
# word nuevo: na se suma block_size: 2063
# word nuevo: ika se suma block_size: 2291
# word nuevo: tutugon se suma block_size: 2523
# word nuevo: sa se suma block_size: 2750
# word nuevo: mga se suma block_size: 2978
# word nuevo: tanong se suma block_size: 3209
# word nuevo: ake se suma block_size: 3437
# word nuevo: nabitawan se suma block_size: 3671
# word nuevo: kung se suma block_size: 3900
# word nuevo: ito se suma block_size: 4128
# word nuevo: totoo se suma block_size: 4358
# word nuevo: pangarap se suma block_size: 4591
# word nuevo: ka se suma block_size: 4818
# word nuevo: bawat se suma block_size: 5048
# word nuevo: sandali se suma block_size: 5280
# word nuevo: langit se suma block_size: 5511
# word nuevo: man se suma block_size: 5739
# word nuevo: ang se suma block_size: 5967
# word nuevo: tingin se suma block_size: 6198
# word nuevo: sayo se suma block_size: 6427
# word nuevo: sana se suma block_size: 6656
# word nuevo: marat se suma block_size: 6886
# word nuevo: hanggang se suma block_size: 7119
# word nuevo: dito se suma block_size: 7348
# word nuevo: lang se suma block_size: 7577
# word nuevo: yata se suma block_size: 7806
# word nuevo: kaya se suma block_size: 8035
# word nuevo: kong se suma block_size: 8264
# word nuevo: gawin se suma block_size: 8494
# word nuevo: mangarap se suma block_size: 8727
# word nuevo: bumulong se suma block_size: 8960
# word nuevo: hangin se suma block_size: 9191
# word nuevo: kailan se suma block_size: 9422
# word nuevo: darat se suma block_size: 9652
# word nuevo: ulit se suma block_size: 9881
# word nuevo: isang se suma block_size: 10111
# word nuevo: lilingon se suma block_size: 10344
# word nuevo: muli se suma block_size: 10573
# word nuevo: tinig se suma block_size: 10803
# word nuevo: mong se suma block_size: 11032
# word nuevo: kay se suma block_size: 11260
# word nuevo: lamig se suma block_size: 11490
# word nuevo: iyong se suma block_size: 11720
# word nuevo: ngiti se suma block_size: 11950
# word nuevo: akin se suma block_size: 12179
# word nuevo: ay se suma block_size: 12406
# word nuevo: nakapagbigay se suma block_size: 12643
# word nuevo: pansin se suma block_size: 12874
# word nuevo: ikaw se suma block_size: 13103
# word nuevo: ba se suma block_size: 13330
# word nuevo: barbi se suma block_size: 13560
# word nuevo: cradl se suma block_size: 13790
# word nuevo: trip se suma block_size: 14019
# word nuevo: pinoy se suma block_size: 14249
# word nuevo: classic se suma block_size: 14481
# word nuevo: rock se suma block_size: 14710
# Block 0 written to disk as ./blocks/block_0.txt
# word nuevo: tree se suma block_size: 14939
# word nuevo: sing se suma block_size: 15168
# word nuevo: wind se suma block_size: 15397
# word nuevo: sky se suma block_size: 15625
# word nuevo: blue se suma block_size: 15854
# word nuevo: angel se suma block_size: 16084
# word nuevo: smile se suma block_size: 16314
# word nuevo: saw se suma block_size: 16542
# word nuevo: lone se suma block_size: 16771
# word nuevo: bench se suma block_size: 17001
# word nuevo: half se suma block_size: 17230
# word nuevo: past se suma block_size: 17459
# word nuevo: four se suma block_size: 17688
# word nuevo: kiss se suma block_size: 17917
# word nuevo: soft se suma block_size: 18146
# word nuevo: hand se suma block_size: 18375
# word nuevo: 6 se suma block_size: 18601
# word nuevo: lip se suma block_size: 18829
# word nuevo: thought se suma block_size: 19061
# word nuevo: hey se suma block_size: 19289
# word nuevo: feel se suma block_size: 19518
# word nuevo: aliv se suma block_size: 19747
# word nuevo: park se suma block_size: 19976
# word nuevo: sign se suma block_size: 20205
# word nuevo: said se suma block_size: 20434
# word nuevo: close se suma block_size: 20664
# word nuevo: jump se suma block_size: 20893
# word nuevo: fenc se suma block_size: 21122
# word nuevo: care se suma block_size: 21351
# word nuevo: danc se suma block_size: 21580
# word nuevo: midnight se suma block_size: 21813
# word nuevo: sun se suma block_size: 22041
# word nuevo: love se suma block_size: 22270
# word nuevo: without se suma block_size: 22502
# word nuevo: know se suma block_size: 22731
# word nuevo: laugh se suma block_size: 22961
# word nuevo: felt se suma block_size: 23190
# word nuevo: free se suma block_size: 23419
# word nuevo: steadi se suma block_size: 23650
# word nuevo: rollin se suma block_size: 23881
# word nuevo: loss se suma block_size: 24110
# word nuevo: hard se suma block_size: 24339
# word nuevo: workout se suma block_size: 24599
# Block 0 written to disk as ./blocks/block_0.txt
# word nuevo: yeah se suma block_size: 24856
# word nuevo: spyderman se suma block_size: 25090
# word nuevo: freez se suma block_size: 25320
# word nuevo: full se suma block_size: 25549
# word nuevo: effect se suma block_size: 25780
# word nuevo: uh se suma block_size: 26007
# word nuevo: huh se suma block_size: 26235
# word nuevo: readi se suma block_size: 26465
# word nuevo: ron se suma block_size: 26693
# word nuevo: biv se suma block_size: 26921
# word nuevo: slick se suma block_size: 27151
# word nuevo: oh se suma block_size: 27378
# word nuevo: break se suma block_size: 27608
# word nuevo: girl se suma block_size: 27837
# word nuevo: must se suma block_size: 28066
# word nuevo: warn se suma block_size: 28295
# word nuevo: sens se suma block_size: 28524
# word nuevo: someth se suma block_size: 28755
# word nuevo: strang se suma block_size: 28986
# word nuevo: mind se suma block_size: 29215
# word nuevo: situat se suma block_size: 29446
# word nuevo: serious se suma block_size: 29678
# word nuevo: let se suma block_size: 29906
# word nuevo: cure se suma block_size: 30135
# word nuevo: caus se suma block_size: 30364
# word nuevo: run se suma block_size: 30592
# word nuevo: time se suma block_size: 30821
# word nuevo: beauti se suma block_size: 31052
# word nuevo: relationship se suma block_size: 31289
# word nuevo: seem se suma block_size: 31518
# word nuevo: start se suma block_size: 31748
# word nuevo: dead se suma block_size: 31977
# word nuevo: togeth se suma block_size: 32236
# word nuevo: heart se suma block_size: 32466
# word nuevo: drivin se suma block_size: 32697
# word nuevo: find se suma block_size: 32954
# word nuevo: get se suma block_size: 33182
# word nuevo: head se suma block_size: 33411
# word nuevo: miss se suma block_size: 33640
# word nuevo: wrong se suma block_size: 33898
# word nuevo: move se suma block_size: 34127
# word nuevo: poison se suma block_size: 34358
# word nuevo: never se suma block_size: 34588
# word nuevo: trust se suma block_size: 34818
# word nuevo: big se suma block_size: 35046
# word nuevo: butt se suma block_size: 35275
# word nuevo: caution se suma block_size: 35535
# word nuevo: meet se suma block_size: 35764
# word nuevo: fli se suma block_size: 35992
# word nuevo: portion se suma block_size: 36252
# word nuevo: think se suma block_size: 36482
# word nuevo: best se suma block_size: 36711
# word nuevo: thing se suma block_size: 36941
# word nuevo: world se suma block_size: 37171
# word nuevo: drive se suma block_size: 37401
# word nuevo: right se suma block_size: 37631
# word nuevo: steal se suma block_size: 37861
# word nuevo: blind se suma block_size: 38091
# word nuevo: bewar se suma block_size: 38321
# word nuevo: schemin se suma block_size: 38553
# word nuevo: make se suma block_size: 38782
# word nuevo: dreamin se suma block_size: 39014
# word nuevo: fall se suma block_size: 39243
# word nuevo: screamin se suma block_size: 39476
# word nuevo: demon se suma block_size: 39706
# word nuevo: hoo se suma block_size: 39934
# word nuevo: movin se suma block_size: 40164
# word nuevo: slow se suma block_size: 40393
# word nuevo: lookin se suma block_size: 40624
# word nuevo: mellow se suma block_size: 40855
# word nuevo: fellow se suma block_size: 41086
# Writing block 0 to disk (block size: 41086 bytes)
# Block 0 written to disk as ./blocks/block_0.txt
# word nuevo: like se suma block_size: 229
# word nuevo: devo se suma block_size: 458
# word nuevo: gettin se suma block_size: 689
# word nuevo: paid se suma block_size: 918
# word nuevo: laid se suma block_size: 1147
# word nuevo: better se suma block_size: 1378
# word nuevo: lay se suma block_size: 1606
# word nuevo: low se suma block_size: 1834
# word nuevo: schemin se suma block_size: 2066
# word nuevo: hous se suma block_size: 2295
# word nuevo: money se suma block_size: 2525
# word nuevo: whole se suma block_size: 2755
# word nuevo: show se suma block_size: 2984
# word nuevo: pro se suma block_size: 3212
# word nuevo: ho se suma block_size: 3439
# word nuevo: cut se suma block_size: 3667
# word nuevo: aaa se suma block_size: 3895
# word nuevo: fro se suma block_size: 4123
# word nuevo: see se suma block_size: 4351
# word nuevo: sayin se suma block_size: 4581
# word nuevo: huh se suma block_size: 4809
# word nuevo: winner se suma block_size: 5040
# word nuevo: know se suma block_size: 5269
# word nuevo: loser se suma block_size: 5499
# word nuevo: crew se suma block_size: 5728
# word nuevo: use se suma block_size: 5956
# word nuevo: poison se suma block_size: 6187
# word nuevo: park se suma block_size: 6416
# word nuevo: shake se suma block_size: 6646
# word nuevo: breakin se suma block_size: 6878
# word nuevo: takin se suma block_size: 7108
# word nuevo: em se suma block_size: 7335
# word nuevo: night se suma block_size: 7565
# word nuevo: play se suma block_size: 7794
# word nuevo: wall se suma block_size: 8023
# word nuevo: checkin se suma block_size: 8255
# word nuevo: fella se suma block_size: 8485
# word nuevo: high se suma block_size: 8714
# word nuevo: keepin se suma block_size: 8945
# word nuevo: one se suma block_size: 9173
# word nuevo: eye se suma block_size: 9401
# word nuevo: open se suma block_size: 9630
# word nuevo: still se suma block_size: 9860
# word nuevo: clockin se suma block_size: 10092
# word nuevo: hoe se suma block_size: 10320
# word nuevo: particular se suma block_size: 10555
# word nuevo: girl se suma block_size: 10784
# word nuevo: stood se suma block_size: 11014
# word nuevo: rest se suma block_size: 11243
# word nuevo: power se suma block_size: 11473
# word nuevo: chest se suma block_size: 11703
# word nuevo: michael se suma block_size: 11935
# word nuevo: biv se suma block_size: 12163
# word nuevo: runnin se suma block_size: 12394
# word nuevo: bell se suma block_size: 12623
# word nuevo: yo se suma block_size: 12850
# word nuevo: slick se suma block_size: 13080
# word nuevo: blow se suma block_size: 13309
# word nuevo: drivin se suma block_size: 13540
# word nuevo: mind se suma block_size: 13769
# word nuevo: hard se suma block_size: 13998
# word nuevo: find se suma block_size: 14227
# word nuevo: get se suma block_size: 14455
# word nuevo: head se suma block_size: 14684
# word nuevo: miss se suma block_size: 14913
# word nuevo: kiss se suma block_size: 15142
# word nuevo: love se suma block_size: 15371
# word nuevo: wrong se suma block_size: 15601
# word nuevo: move se suma block_size: 15830
# word nuevo: dead se suma block_size: 16059
# word nuevo: never se suma block_size: 16289
# word nuevo: trust se suma block_size: 16519
# word nuevo: big se suma block_size: 16747
# word nuevo: butt se suma block_size: 16976
# word nuevo: smile se suma block_size: 17206
# word nuevo: end se suma block_size: 17434
# word nuevo: mike se suma block_size: 17663
# word nuevo: yeah se suma block_size: 17892
# word nuevo: b se suma block_size: 18118
# word nuevo: full se suma block_size: 18347
# word nuevo: effect se suma block_size: 18578
# word nuevo: wassup se suma block_size: 18809
# word nuevo: ralph se suma block_size: 19039
# word nuevo: johnni se suma block_size: 19270
# word nuevo: g se suma block_size: 19496
# word nuevo: forget se suma block_size: 19727
# word nuevo: boy se suma block_size: 19955
# word nuevo: brown se suma block_size: 20185
# word nuevo: ne se suma block_size: 20412
# word nuevo: na se suma block_size: 20639
# word nuevo: gold se suma block_size: 20868
# word nuevo: back se suma block_size: 21097
# word nuevo: day se suma block_size: 21325
# word nuevo: r se suma block_size: 21551
# word nuevo: new se suma block_size: 21779
# word nuevo: jack se suma block_size: 22008
# word nuevo: swing se suma block_size: 22238
# word nuevo: swingbeat se suma block_size: 22472
# word nuevo: rnb se suma block_size: 22700
# word nuevo: etc se suma block_size: 22928
# Block 1 written to disk as ./blocks/block_1.txt
# word nuevo: realli se suma block_size: 23159
# word nuevo: stay se suma block_size: 23388
# word nuevo: babi se suma block_size: 23617
# word nuevo: cold se suma block_size: 23846
# word nuevo: outsid se suma block_size: 24077
# word nuevo: got se suma block_size: 24305
# word nuevo: go se suma block_size: 24532
# word nuevo: away se suma block_size: 24761
# word nuevo: even se suma block_size: 24990
# word nuevo: hope se suma block_size: 25219
# word nuevo: drop se suma block_size: 25448
# word nuevo: nice se suma block_size: 25677
# word nuevo: hold se suma block_size: 25906
# word nuevo: hand se suma block_size: 26135
# word nuevo: ice se suma block_size: 26391
# word nuevo: mother se suma block_size: 26622
# word nuevo: start se suma block_size: 26852
# word nuevo: worri se suma block_size: 27082
# word nuevo: beauti se suma block_size: 27313
# word nuevo: hurri se suma block_size: 27543
# word nuevo: father se suma block_size: 27774
# word nuevo: pace se suma block_size: 28003
# word nuevo: floor se suma block_size: 28233
# word nuevo: listen se suma block_size: 28464
# word nuevo: fireplac se suma block_size: 28697
# word nuevo: roar se suma block_size: 28926
# word nuevo: scurri se suma block_size: 29185
# word nuevo: pleas se suma block_size: 29415
# word nuevo: well se suma block_size: 29644
# word nuevo: mayb se suma block_size: 29873
# word nuevo: half se suma block_size: 30102
# word nuevo: drink se suma block_size: 30332
# word nuevo: put se suma block_size: 30560
# word nuevo: record se suma block_size: 30791
# word nuevo: pour se suma block_size: 31020
# word nuevo: neighbor se suma block_size: 31253
# word nuevo: might se suma block_size: 31483
# word nuevo: think se suma block_size: 31713
# word nuevo: bad se suma block_size: 31941
# word nuevo: say se suma block_size: 32169
# word nuevo: cab se suma block_size: 32397
# word nuevo: wish se suma block_size: 32626
# word nuevo: knew se suma block_size: 32855
# word nuevo: starlight se suma block_size: 33117
# word nuevo: break se suma block_size: 33347
# word nuevo: spell se suma block_size: 33577
# word nuevo: take se suma block_size: 33806
# word nuevo: hat se suma block_size: 34034
# word nuevo: hair se suma block_size: 34263
# word nuevo: look se suma block_size: 34492
# word nuevo: swell se suma block_size: 34722
# word nuevo: ought se suma block_size: 34952
# word nuevo: sir se suma block_size: 35180
# word nuevo: closer se suma block_size: 35467
# word nuevo: least se suma block_size: 35697
# word nuevo: gonna se suma block_size: 35927
# word nuevo: tri se suma block_size: 36155
# word nuevo: sens se suma block_size: 36384
# word nuevo: hurt se suma block_size: 36613
# word nuevo: pride se suma block_size: 36843
# word nuevo: simpli se suma block_size: 37074
# word nuevo: must se suma block_size: 37303
# word nuevo: answer se suma block_size: 37562
# word nuevo: said se suma block_size: 37791
# word nuevo: welcom se suma block_size: 38022
# word nuevo: lucki se suma block_size: 38252
# word nuevo: warm se suma block_size: 38481
# word nuevo: window se suma block_size: 38712
# word nuevo: storm se suma block_size: 38942
# word nuevo: sister se suma block_size: 39173
# word nuevo: suspici se suma block_size: 39405
# word nuevo: gosh se suma block_size: 39634
# word nuevo: lip se suma block_size: 39862
# word nuevo: delici se suma block_size: 40093
# word nuevo: brother se suma block_size: 40325
# word nuevo: door se suma block_size: 40554
# word nuevo: wave se suma block_size: 40783
# word nuevo: upon se suma block_size: 41012
# Writing block 1 to disk (block size: 41012 bytes)
# Block 1 written to disk as ./blocks/block_1.txt
# word nuevo: tropic se suma block_size: 231
# word nuevo: shore se suma block_size: 461
# word nuevo: maiden se suma block_size: 692
# word nuevo: aunt se suma block_size: 921
# word nuevo: mind se suma block_size: 1150
# word nuevo: vicious se suma block_size: 1382
# word nuevo: oh se suma block_size: 1609
# word nuevo: lip se suma block_size: 1837
# word nuevo: delici se suma block_size: 2068
# word nuevo: mayb se suma block_size: 2297
# word nuevo: cigarett se suma block_size: 2530
# word nuevo: never se suma block_size: 2760
# word nuevo: blizzard se suma block_size: 2993
# word nuevo: hey se suma block_size: 3221
# word nuevo: got se suma block_size: 3449
# word nuevo: go se suma block_size: 3676
# word nuevo: home se suma block_size: 3905
# word nuevo: babi se suma block_size: 4134
# word nuevo: freez se suma block_size: 4364
# word nuevo: say se suma block_size: 4592
# word nuevo: lend se suma block_size: 4821
# word nuevo: coat se suma block_size: 5050
# word nuevo: knee se suma block_size: 5279
# word nuevo: realli se suma block_size: 5510
# word nuevo: grand se suma block_size: 5740
# word nuevo: thrill se suma block_size: 5971
# word nuevo: touch se suma block_size: 6201
# word nuevo: hand se suma block_size: 6430
# word nuevo: see se suma block_size: 6658
# word nuevo: thing se suma block_size: 6888
# word nuevo: bound se suma block_size: 7118
# word nuevo: talk se suma block_size: 7347
# word nuevo: tomorrow se suma block_size: 7580
# word nuevo: think se suma block_size: 7810
# word nuevo: life se suma block_size: 8039
# word nuevo: long se suma block_size: 8268
# word nuevo: sorrow se suma block_size: 8499
# word nuevo: least se suma block_size: 8729
# word nuevo: plenti se suma block_size: 8960
# word nuevo: impli se suma block_size: 9190
# word nuevo: caught se suma block_size: 9421
# word nuevo: pneumonia se suma block_size: 9655
# word nuevo: die se suma block_size: 9883
# word nuevo: stay se suma block_size: 10112
# word nuevo: get se suma block_size: 10340
# word nuevo: old se suma block_size: 10568
# word nuevo: lie se suma block_size: 10796
# word nuevo: cold se suma block_size: 11025
# word nuevo: outsid se suma block_size: 11256
# word nuevo: feat se suma block_size: 11485
# word nuevo: christina se suma block_size: 11719
# word nuevo: aguilera se suma block_size: 11952
# word nuevo: ceelo se suma block_size: 12182
# word nuevo: green se suma block_size: 12412
# word nuevo: magic se suma block_size: 12642
# word nuevo: moment se suma block_size: 12873
# word nuevo: christma se suma block_size: 13106
# word nuevo: soul se suma block_size: 13335
# word nuevo: r se suma block_size: 13561
# word nuevo: b se suma block_size: 13787
# word nuevo: neo se suma block_size: 14015
# Block 2 written to disk as ./blocks/block_2.txt
# word nuevo: busi se suma block_size: 14272
# word nuevo: keep se suma block_size: 14501
# word nuevo: turn se suma block_size: 14730
# word nuevo: wit se suma block_size: 14958
# word nuevo: crimin se suma block_size: 15189
# word nuevo: feel se suma block_size: 15418
# word nuevo: aye se suma block_size: 15646
# word nuevo: bad se suma block_size: 15874
# word nuevo: boy se suma block_size: 16102
# word nuevo: noth se suma block_size: 16331
# word nuevo: bout se suma block_size: 16560
# word nuevo: nada se suma block_size: 16789
# word nuevo: know se suma block_size: 17018
# word nuevo: caus se suma block_size: 17275
# word nuevo: parti se suma block_size: 17505
# word nuevo: yeah se suma block_size: 17734
# word nuevo: worri se suma block_size: 17964
# word nuevo: drama se suma block_size: 18194
# word nuevo: bodi se suma block_size: 18423
# word nuevo: everybodi se suma block_size: 18657
# word nuevo: wild se suma block_size: 18886
# word nuevo: volum se suma block_size: 19116
# word nuevo: dumb se suma block_size: 19373
# word nuevo: litti se suma block_size: 19603
# word nuevo: bang se suma block_size: 19832
# word nuevo: drum se suma block_size: 20061
# word nuevo: stupid se suma block_size: 20320
# word nuevo: come se suma block_size: 20549
# word nuevo: drippin se suma block_size: 20781
# word nuevo: grip se suma block_size: 21010
# word nuevo: let se suma block_size: 21238
# word nuevo: way se suma block_size: 21466
# word nuevo: follow se suma block_size: 21697
# word nuevo: nobodi se suma block_size: 21928
# word nuevo: wake se suma block_size: 22157
# word nuevo: uh se suma block_size: 22384
# word nuevo: kard se suma block_size: 22613
# word nuevo: 2nd se suma block_size: 22841
# word nuevo: digit se suma block_size: 23071
# word nuevo: singl se suma block_size: 23301
# word nuevo: k se suma block_size: 23527
# word nuevo: danc se suma block_size: 23756
# word nuevo: mix se suma block_size: 23984
# word nuevo: pop se suma block_size: 24212
# Block 2 written to disk as ./blocks/block_2.txt
# word nuevo: hold se suma block_size: 24441
# word nuevo: breath se suma block_size: 24672
# word nuevo: look se suma block_size: 24901
# word nuevo: tri se suma block_size: 25157
# word nuevo: darl se suma block_size: 25386
# word nuevo: okay se suma block_size: 25615
# word nuevo: scare se suma block_size: 25845
# word nuevo: frighten se suma block_size: 26078
# word nuevo: time se suma block_size: 26307
# word nuevo: like se suma block_size: 26564
# word nuevo: world se suma block_size: 26794
# word nuevo: hard se suma block_size: 27023
# word nuevo: knock se suma block_size: 27253
# word nuevo: us se suma block_size: 27480
# word nuevo: reason se suma block_size: 27711
# word nuevo: still se suma block_size: 27941
# word nuevo: one se suma block_size: 28169
# word nuevo: els se suma block_size: 28397
# word nuevo: around se suma block_size: 28628
# word nuevo: grown se suma block_size: 28858
# word nuevo: everi se suma block_size: 29088
# word nuevo: day se suma block_size: 29344
# word nuevo: proud se suma block_size: 29574
# word nuevo: swear se suma block_size: 29804
# word nuevo: anyth se suma block_size: 30062
# word nuevo: stop se suma block_size: 30291
# word nuevo: soldier se suma block_size: 30523
# word nuevo: fight se suma block_size: 30753
# word nuevo: darkest se suma block_size: 30985
# word nuevo: shoulder se suma block_size: 31246
# word nuevo: carri se suma block_size: 31476
# word nuevo: worth se suma block_size: 31790
# word nuevo: live se suma block_size: 32019
# word nuevo: make se suma block_size: 32248
# word nuevo: wanna se suma block_size: 32478
# word nuevo: brave se suma block_size: 32708
# word nuevo: depth se suma block_size: 32966
# word nuevo: despair se suma block_size: 33198
# word nuevo: stumbl se suma block_size: 33429
# word nuevo: distanc se suma block_size: 33661
# word nuevo: crumbl se suma block_size: 33892
# word nuevo: ignor se suma block_size: 34122
# word nuevo: rumour se suma block_size: 34353
# word nuevo: jealous se suma block_size: 34585
# word nuevo: disapprov se suma block_size: 34819
# word nuevo: side se suma block_size: 35076
# word nuevo: someth se suma block_size: 35307
# word nuevo: beauti se suma block_size: 35538
# word nuevo: gonna se suma block_size: 35880
# word nuevo: grow se suma block_size: 36109
# word nuevo: learn se suma block_size: 36339
# word nuevo: tear se suma block_size: 36568
# word nuevo: mistak se suma block_size: 36799
# word nuevo: perfect se suma block_size: 37031
# word nuevo: kid se suma block_size: 37315
# word nuevo: fall se suma block_size: 37544
# word nuevo: love se suma block_size: 37773
# word nuevo: tell se suma block_size: 38002
# word nuevo: odd se suma block_size: 38230
# word nuevo: woo se suma block_size: 38458
# word nuevo: ooh se suma block_size: 38686
# word nuevo: jame se suma block_size: 38915
# word nuevo: tw se suma block_size: 39142
# word nuevo: chapter se suma block_size: 39374
# word nuevo: urban se suma block_size: 39604
# word nuevo: contemporari se suma block_size: 39841
# Block 2 written to disk as ./blocks/block_2.txt
# word nuevo: want se suma block_size: 40126
# word nuevo: somebodi se suma block_size: 40359
# word nuevo: money se suma block_size: 40645
# word nuevo: mean se suma block_size: 40874
# word nuevo: shit se suma block_size: 41103
# Writing block 2 to disk (block size: 41103 bytes)
# Block 2 written to disk as ./blocks/block_2.txt
# word nuevo: got se suma block_size: 228
# word nuevo: nobodi se suma block_size: 459
# word nuevo: share se suma block_size: 689
# word nuevo: love se suma block_size: 918
# word nuevo: rule se suma block_size: 1147
# word nuevo: world se suma block_size: 1377
# word nuevo: feel se suma block_size: 1606
# word nuevo: understand se suma block_size: 1841
# word nuevo: like se suma block_size: 2070
# word nuevo: never se suma block_size: 2300
# word nuevo: make se suma block_size: 2529
# word nuevo: give se suma block_size: 2758
# word nuevo: caus se suma block_size: 2987
# word nuevo: show se suma block_size: 3216
# word nuevo: bout se suma block_size: 3445
# word nuevo: real se suma block_size: 3674
# word nuevo: promis se suma block_size: 3905
# word nuevo: anyth se suma block_size: 4135
# word nuevo: satisfi se suma block_size: 4367
# word nuevo: hurt se suma block_size: 4596
# word nuevo: eas se suma block_size: 4824
# word nuevo: pain se suma block_size: 5053
# word nuevo: girl se suma block_size: 5282
# word nuevo: caress se suma block_size: 5513
# word nuevo: frame se suma block_size: 5743
# word nuevo: get se suma block_size: 5971
# word nuevo: worri se suma block_size: 6201
# word nuevo: brain se suma block_size: 6431
# word nuevo: corner se suma block_size: 6662
# word nuevo: want se suma block_size: 6891
# word nuevo: thing se suma block_size: 7121
# word nuevo: persist se suma block_size: 7353
# word nuevo: tri se suma block_size: 7581
# word nuevo: one se suma block_size: 7809
# word nuevo: game se suma block_size: 8038
# word nuevo: play se suma block_size: 8267
# word nuevo: wanna se suma block_size: 8497
# word nuevo: lay se suma block_size: 8725
# word nuevo: stay se suma block_size: 8954
# word nuevo: pray se suma block_size: 9183
# word nuevo: grow se suma block_size: 9412
# word nuevo: old se suma block_size: 9640
# word nuevo: gray se suma block_size: 9869
# word nuevo: good se suma block_size: 10098
# word nuevo: bad se suma block_size: 10326
# word nuevo: time se suma block_size: 10555
# word nuevo: alway se suma block_size: 10785
# word nuevo: true se suma block_size: 11014
# word nuevo: matter se suma block_size: 11245
# word nuevo: say se suma block_size: 11473
# word nuevo: could se suma block_size: 11703
# word nuevo: straight se suma block_size: 11936
# word nuevo: lace se suma block_size: 12165
# word nuevo: appear se suma block_size: 12396
# word nuevo: stimul se suma block_size: 12627
# word nuevo: mind se suma block_size: 12856
# word nuevo: strengthen se suma block_size: 13091
# word nuevo: spirit se suma block_size: 13322
# word nuevo: voic se suma block_size: 13551
# word nuevo: reason se suma block_size: 13782
# word nuevo: tryna se suma block_size: 14012
# word nuevo: hear se suma block_size: 14241
# word nuevo: fear se suma block_size: 14470
# word nuevo: near se suma block_size: 14699
# word nuevo: sit se suma block_size: 14927
# word nuevo: sofa se suma block_size: 15156
# word nuevo: littl se suma block_size: 15386
# word nuevo: closer se suma block_size: 15617
# word nuevo: touch se suma block_size: 15847
# word nuevo: right se suma block_size: 16077
# word nuevo: man se suma block_size: 16305
# word nuevo: suppos se suma block_size: 16536
# word nuevo: knew se suma block_size: 16765
# word nuevo: chose se suma block_size: 16995
# word nuevo: ride se suma block_size: 17224
# word nuevo: soldier se suma block_size: 17456
# word nuevo: soul se suma block_size: 17685
# word nuevo: toy se suma block_size: 17913
# word nuevo: dealin se suma block_size: 18144
# word nuevo: boy se suma block_size: 18372
# word nuevo: empti se suma block_size: 18602
# word nuevo: insid se suma block_size: 18832
# word nuevo: fill se suma block_size: 19061
# word nuevo: void se suma block_size: 19290
# word nuevo: spend se suma block_size: 19520
# word nuevo: woman se suma block_size: 19750
# word nuevo: listen se suma block_size: 19981
# word nuevo: shine se suma block_size: 20211
# word nuevo: baguett se suma block_size: 20443
# word nuevo: diamond se suma block_size: 20675
# word nuevo: glisten se suma block_size: 20907
# word nuevo: impress se suma block_size: 21139
# word nuevo: car se suma block_size: 21367
# word nuevo: wealth se suma block_size: 21598
# word nuevo: drive se suma block_size: 21828
# word nuevo: rather se suma block_size: 22059
# word nuevo: heartfelt se suma block_size: 22293
# word nuevo: heart se suma block_size: 22523
# word nuevo: melt se suma block_size: 22752
# word nuevo: prove se suma block_size: 22982
# word nuevo: import se suma block_size: 23213
# word nuevo: els se suma block_size: 23441
# word nuevo: worthwhil se suma block_size: 23675
# word nuevo: special se suma block_size: 23907
# word nuevo: first se suma block_size: 24137
# word nuevo: child se suma block_size: 24367
# word nuevo: see se suma block_size: 24595
# word nuevo: face se suma block_size: 24824
# word nuevo: eye se suma block_size: 25052
# word nuevo: met se suma block_size: 25280
# word nuevo: togeth se suma block_size: 25511
# word nuevo: jet se suma block_size: 25739
# word nuevo: buy se suma block_size: 25967
# word nuevo: yet se suma block_size: 26195
# word nuevo: hold se suma block_size: 26424
# word nuevo: mold se suma block_size: 26653
# word nuevo: know se suma block_size: 26882
# word nuevo: let se suma block_size: 27110
# word nuevo: tellin se suma block_size: 27341
# word nuevo: known se suma block_size: 27571
# word nuevo: told se suma block_size: 27800
# word nuevo: mma se suma block_size: 28028
# word nuevo: whatev se suma block_size: 28259
# word nuevo: go se suma block_size: 28486
# word nuevo: sing se suma block_size: 28715
# word nuevo: sad se suma block_size: 28943
# word nuevo: song se suma block_size: 29172
# word nuevo: babi se suma block_size: 29401
# word nuevo: wait se suma block_size: 29630
# word nuevo: long se suma block_size: 29859
# word nuevo: need se suma block_size: 30088
# word nuevo: light se suma block_size: 30318
# word nuevo: air se suma block_size: 30546
# word nuevo: breath se suma block_size: 30777
# word nuevo: leav se suma block_size: 31006
# word nuevo: doubt se suma block_size: 31236
# word nuevo: believ se suma block_size: 31467
# word nuevo: lie se suma block_size: 31695
# word nuevo: cheat se suma block_size: 31925
# word nuevo: deceiv se suma block_size: 32156
# word nuevo: weak se suma block_size: 32385
# word nuevo: strong se suma block_size: 32616
# word nuevo: belong se suma block_size: 32847
# word nuevo: perfect se suma block_size: 33079
# word nuevo: wrong se suma block_size: 33309
# word nuevo: keep se suma block_size: 33538
# word nuevo: away se suma block_size: 33767
# word nuevo: harm se suma block_size: 33996
# word nuevo: protect se suma block_size: 34228
# word nuevo: wrap se suma block_size: 34457
# word nuevo: arm se suma block_size: 34685
# word nuevo: neglect se suma block_size: 34917
# word nuevo: awar se suma block_size: 35146
# word nuevo: rare se suma block_size: 35375
# word nuevo: moment se suma block_size: 35606
# word nuevo: despair se suma block_size: 35838
# word nuevo: courag se suma block_size: 36069
# word nuevo: scare se suma block_size: 36299
# word nuevo: loyal se suma block_size: 36529
# word nuevo: soon se suma block_size: 36758
# word nuevo: saw se suma block_size: 36986
# word nuevo: around se suma block_size: 37217
# word nuevo: plant se suma block_size: 37447
# word nuevo: seed se suma block_size: 37676
# word nuevo: soil se suma block_size: 37905
# word nuevo: night se suma block_size: 38135
# word nuevo: bend se suma block_size: 38364
# word nuevo: bed se suma block_size: 38592
# word nuevo: coil se suma block_size: 38821
# word nuevo: queen se suma block_size: 39051
# word nuevo: therefor se suma block_size: 39284
# word nuevo: treat se suma block_size: 39514
# word nuevo: royal se suma block_size: 39744
# word nuevo: simpli se suma block_size: 39975
# word nuevo: ador se suma block_size: 40204
# word nuevo: fade se suma block_size: 40433
# word nuevo: goe se suma block_size: 40661
# word nuevo: sister se suma block_size: 40892
# word nuevo: diddi se suma block_size: 41122
# Writing block 3 to disk (block size: 41122 bytes)
# Block 3 written to disk as ./blocks/block_3.txt
# word nuevo: forev se suma block_size: 230
# word nuevo: swingbeat se suma block_size: 464
# word nuevo: old se suma block_size: 692
# word nuevo: skool se suma block_size: 922
# word nuevo: new se suma block_size: 1150
# word nuevo: jack se suma block_size: 1379
# word nuevo: swing se suma block_size: 1609
# word nuevo: r se suma block_size: 1835
# word nuevo: b se suma block_size: 2061
# word nuevo: hip se suma block_size: 2289
# word nuevo: hop se suma block_size: 2517
# word nuevo: urban se suma block_size: 2747
# Block 4 written to disk as ./blocks/block_4.txt
# word nuevo: feel se suma block_size: 2976
# word nuevo: good se suma block_size: 3205
# word nuevo: everybodi se suma block_size: 3439
# word nuevo: tender se suma block_size: 3670
# word nuevo: lover se suma block_size: 3900
# word nuevo: love se suma block_size: 4129
# word nuevo: eleanor se suma block_size: 4361
# word nuevo: rigbi se suma block_size: 4591
# word nuevo: spend se suma block_size: 4821
# word nuevo: half se suma block_size: 5050
# word nuevo: life se suma block_size: 5279
# word nuevo: alon se suma block_size: 5508
# word nuevo: fault se suma block_size: 5738
# word nuevo: made se suma block_size: 5967
# word nuevo: decis se suma block_size: 6197
# word nuevo: place se suma block_size: 6427
# word nuevo: home se suma block_size: 6656
# word nuevo: right se suma block_size: 6886
# word nuevo: go se suma block_size: 7113
# word nuevo: limit se suma block_size: 7343
# word nuevo: believ se suma block_size: 7574
# word nuevo: open se suma block_size: 7803
# word nuevo: even se suma block_size: 8032
# word nuevo: give se suma block_size: 8261
# word nuevo: caus se suma block_size: 8490
# word nuevo: start se suma block_size: 8720
# word nuevo: hold se suma block_size: 8949
# word nuevo: make se suma block_size: 9178
# word nuevo: get se suma block_size: 9406
# word nuevo: tri se suma block_size: 9634
# word nuevo: work se suma block_size: 9863
# word nuevo: time se suma block_size: 10092
# word nuevo: girl se suma block_size: 10321
# word nuevo: sorri se suma block_size: 10551
# word nuevo: well se suma block_size: 10780
# word nuevo: never se suma block_size: 11010
# word nuevo: meant se suma block_size: 11240
# word nuevo: hurt se suma block_size: 11469
# word nuevo: break se suma block_size: 11699
# word nuevo: heart se suma block_size: 11929
# word nuevo: broken se suma block_size: 12160
# word nuevo: littl se suma block_size: 12390
# word nuevo: ever se suma block_size: 12619
# word nuevo: spite se suma block_size: 12849
# word nuevo: much se suma block_size: 13078
# word nuevo: precious se suma block_size: 13311
# word nuevo: greater se suma block_size: 13543
# word nuevo: us se suma block_size: 13770
# word nuevo: enough se suma block_size: 14001
# word nuevo: keep se suma block_size: 14230
# word nuevo: look se suma block_size: 14459
# word nuevo: want se suma block_size: 14688
# word nuevo: sky se suma block_size: 14916
# word nuevo: na se suma block_size: 15143
# word nuevo: babyfac se suma block_size: 15375
# Block 4 written to disk as ./blocks/block_4.txt
# word nuevo: run se suma block_size: 15743
# word nuevo: away se suma block_size: 15972
# word nuevo: colder se suma block_size: 16231
# word nuevo: unit se suma block_size: 16488
# word nuevo: closer se suma block_size: 16719
# word nuevo: anyth se suma block_size: 16949
# word nuevo: king se suma block_size: 17178
# word nuevo: queen se suma block_size: 17408
# word nuevo: let se suma block_size: 17692
# word nuevo: danc se suma block_size: 17921
# word nuevo: play se suma block_size: 18150
# word nuevo: gonna se suma block_size: 18408
# word nuevo: stop se suma block_size: 18637
# word nuevo: take se suma block_size: 18866
# word nuevo: night se suma block_size: 19096
# word nuevo: hideaway se suma block_size: 19329
# word nuevo: til se suma block_size: 19585
# word nuevo: end se suma block_size: 19813
# word nuevo: insid se suma block_size: 20043
# word nuevo: cloud se suma block_size: 20273
# word nuevo: promis se suma block_size: 20504
# word nuevo: stay se suma block_size: 20733
# word nuevo: moment se suma block_size: 20992
# word nuevo: count se suma block_size: 21222
# word nuevo: star se suma block_size: 21451
# word nuevo: hide se suma block_size: 21708
# word nuevo: feat se suma block_size: 21937
# word nuevo: envi se suma block_size: 22166
# word nuevo: monro se suma block_size: 22396
# word nuevo: blasterjaxx se suma block_size: 22632
# word nuevo: big se suma block_size: 22860
# word nuevo: room se suma block_size: 23089
# word nuevo: edm se suma block_size: 23317
# word nuevo: spinnin se suma block_size: 23549
# word nuevo: record se suma block_size: 23780
# Block 4 written to disk as ./blocks/block_4.txt
# word nuevo: ho se suma block_size: 24007
# word nuevo: una se suma block_size: 24235
# word nuevo: cosa se suma block_size: 24464
# word nuevo: da se suma block_size: 24691
# word nuevo: dirti se suma block_size: 24921
# word nuevo: tempo se suma block_size: 25151
# word nuevo: non se suma block_size: 25379
# word nuevo: mai se suma block_size: 25607
# word nuevo: trovato se suma block_size: 25839
# word nuevo: il se suma block_size: 26066
# word nuevo: momento se suma block_size: 26298
# word nuevo: potrei se suma block_size: 26529
# word nuevo: farlo se suma block_size: 26759
# word nuevo: qui se suma block_size: 26987
# word nuevo: mi se suma block_size: 27214
# word nuevo: importa se suma block_size: 27446
# word nuevo: se se suma block_size: 27673
# word nuevo: questa se suma block_size: 27904
# word nuevo: gent se suma block_size: 28133
# word nuevo: guarda se suma block_size: 28364
# word nuevo: ridendo se suma block_size: 28596
# word nuevo: giuro se suma block_size: 28826
# word nuevo: l se suma block_size: 29052
# word nuevo: altra se suma block_size: 29282
# word nuevo: nott se suma block_size: 29511
# word nuevo: è se suma block_size: 29753
# word nuevo: stato se suma block_size: 29983
# word nuevo: bello se suma block_size: 30213
# word nuevo: esci se suma block_size: 30442
# word nuevo: più se suma block_size: 30686
# word nuevo: dal se suma block_size: 30914
# word nuevo: mio se suma block_size: 31142
# word nuevo: cervello se suma block_size: 31375
# word nuevo: basterebb se suma block_size: 31609
# word nuevo: un se suma block_size: 31836
# word nuevo: solo se suma block_size: 32065
# word nuevo: anello se suma block_size: 32296
# word nuevo: tu se suma block_size: 32523
# word nuevo: vali se suma block_size: 32752
# word nuevo: di se suma block_size: 32979
# word nuevo: ogni se suma block_size: 33208
# word nuevo: gioiello se suma block_size: 33441
# word nuevo: e se suma block_size: 33667
# word nuevo: chissà se suma block_size: 33914
# word nuevo: quando se suma block_size: 34145
# word nuevo: parti se suma block_size: 34375
# word nuevo: poi se suma block_size: 34603
# word nuevo: ritorni se suma block_size: 34835
# word nuevo: dimmi se suma block_size: 35065
# word nuevo: questo se suma block_size: 35296
# word nuevo: sentimento se suma block_size: 35531
# word nuevo: vale se suma block_size: 35760
# word nuevo: anch se suma block_size: 35989
# word nuevo: per se suma block_size: 36217
# word nuevo: te se suma block_size: 36444
# word nuevo: balla se suma block_size: 36674
# word nuevo: finché se suma block_size: 36921
# word nuevo: rimanendo se suma block_size: 37155
# word nuevo: ad se suma block_size: 37382
# word nuevo: occhi se suma block_size: 37612
# word nuevo: chiusi se suma block_size: 37843
# word nuevo: dai se suma block_size: 38071
# word nuevo: bacio se suma block_size: 38301
# word nuevo: ti se suma block_size: 38528
# word nuevo: scusi se suma block_size: 38758
# word nuevo: resta se suma block_size: 38988
# word nuevo: secondo se suma block_size: 39220
# word nuevo: perché se suma block_size: 39467
# word nuevo: volevo se suma block_size: 39698
# word nuevo: dedicar se suma block_size: 39930
# word nuevo: mill se suma block_size: 40159
# word nuevo: canzoni se suma block_size: 40391
# word nuevo: scritt se suma block_size: 40622
# word nuevo: chitarra se suma block_size: 40855
# word nuevo: accordar se suma block_size: 41088
# Writing block 4 to disk (block size: 41088 bytes)
# Block 4 written to disk as ./blocks/block_4.txt
# word nuevo: quell se suma block_size: 230
# word nuevo: notti se suma block_size: 460
# word nuevo: fino se suma block_size: 689
# word nuevo: quando se suma block_size: 920
# word nuevo: sale se suma block_size: 1149
# word nuevo: il se suma block_size: 1376
# word nuevo: sole se suma block_size: 1605
# word nuevo: e se suma block_size: 1831
# word nuevo: perdi se suma block_size: 2061
# word nuevo: conto se suma block_size: 2291
# word nuevo: dell se suma block_size: 2520
# word nuevo: ore se suma block_size: 2748
# word nuevo: ti se suma block_size: 2975
# word nuevo: volevo se suma block_size: 3206
# word nuevo: dedicar se suma block_size: 3438
# word nuevo: quello se suma block_size: 3669
# word nuevo: che se suma block_size: 3897
# word nuevo: provo se suma block_size: 4127
# word nuevo: non se suma block_size: 4355
# word nuevo: cos se suma block_size: 4583
# word nuevo: è se suma block_size: 4825
# word nuevo: diciamo se suma block_size: 5057
# word nuevo: per se suma block_size: 5285
# word nuevo: sempr se suma block_size: 5515
# word nuevo: perché se suma block_size: 5762
# word nuevo: mai se suma block_size: 5990
# word nuevo: nulla se suma block_size: 6220
# word nuevo: dura se suma block_size: 6449
# word nuevo: eterno se suma block_size: 6680
# word nuevo: se se suma block_size: 6907
# word nuevo: credi se suma block_size: 7137
# word nuevo: troppo se suma block_size: 7368
# word nuevo: nei se suma block_size: 7596
# word nuevo: sogni se suma block_size: 7826
# word nuevo: poi se suma block_size: 8054
# word nuevo: risvegliano se suma block_size: 8290
# word nuevo: sul se suma block_size: 8518
# word nuevo: più se suma block_size: 8762
# word nuevo: bello se suma block_size: 8992
# word nuevo: tutto se suma block_size: 9222
# word nuevo: sembra se suma block_size: 9453
# word nuevo: un se suma block_size: 9680
# word nuevo: déjà se suma block_size: 9925
# word nuevo: vu se suma block_size: 10152
# word nuevo: mill se suma block_size: 10381
# word nuevo: parol se suma block_size: 10611
# word nuevo: alla se suma block_size: 10840
# word nuevo: tv se suma block_size: 11067
# word nuevo: coca se suma block_size: 11296
# word nuevo: cola se suma block_size: 11525
# word nuevo: malibu se suma block_size: 11756
# word nuevo: balliamo se suma block_size: 11989
# word nuevo: come se suma block_size: 12218
# word nuevo: una se suma block_size: 12446
# word nuevo: tribù se suma block_size: 12692
# word nuevo: chissà se suma block_size: 12939
# word nuevo: parti se suma block_size: 13169
# word nuevo: ritorni se suma block_size: 13401
# word nuevo: qui se suma block_size: 13629
# word nuevo: da se suma block_size: 13856
# word nuevo: dimmi se suma block_size: 14086
# word nuevo: questo se suma block_size: 14317
# word nuevo: sentimento se suma block_size: 14552
# word nuevo: vale se suma block_size: 14781
# word nuevo: anch se suma block_size: 15010
# word nuevo: te se suma block_size: 15237
# word nuevo: balla se suma block_size: 15467
# word nuevo: finché se suma block_size: 15714
# word nuevo: rimanendo se suma block_size: 15948
# word nuevo: ad se suma block_size: 16175
# word nuevo: occhi se suma block_size: 16405
# word nuevo: chiusi se suma block_size: 16636
# word nuevo: mi se suma block_size: 16863
# word nuevo: dai se suma block_size: 17091
# word nuevo: bacio se suma block_size: 17321
# word nuevo: scusi se suma block_size: 17551
# word nuevo: resta se suma block_size: 17781
# word nuevo: solo se suma block_size: 18010
# word nuevo: secondo se suma block_size: 18242
# word nuevo: canzoni se suma block_size: 18474
# word nuevo: scritt se suma block_size: 18705
# word nuevo: chitarra se suma block_size: 18938
# word nuevo: accordar se suma block_size: 19171
# word nuevo: quelli se suma block_size: 19402
# word nuevo: fare se suma block_size: 19631
# word nuevo: seren se suma block_size: 19861
# word nuevo: sere se suma block_size: 20090
# word nuevo: nere se suma block_size: 20319
# word nuevo: aserej se suma block_size: 20550
# word nuevo: seguo se suma block_size: 20780
# word nuevo: la se suma block_size: 21007
# word nuevo: moda se suma block_size: 21236
# word nuevo: ritorno se suma block_size: 21468
# word nuevo: vinil se suma block_size: 21698
# word nuevo: maradona se suma block_size: 21931
# word nuevo: era se suma block_size: 22159
# word nuevo: meglio se suma block_size: 22390
# word nuevo: di se suma block_size: 22617
# word nuevo: pelé se suma block_size: 22862
# word nuevo: calcio se suma block_size: 23093
# word nuevo: femminil se suma block_size: 23326
# word nuevo: sicuro se suma block_size: 23557
# word nuevo: viril se suma block_size: 23787
# word nuevo: donn se suma block_size: 24016
# word nuevo: contro se suma block_size: 24247
# word nuevo: maschi se suma block_size: 24478
# word nuevo: servono se suma block_size: 24710
# word nuevo: entrambi se suma block_size: 24943
# word nuevo: diversi se suma block_size: 25175
# word nuevo: gli se suma block_size: 25403
# word nuevo: deg se suma block_size: 25631
# word nuevo: huski se suma block_size: 25861
# word nuevo: amo se suma block_size: 26089
# word nuevo: incostanti se suma block_size: 26324
# word nuevo: heidi se suma block_size: 26554
# word nuevo: spog se suma block_size: 26783
# word nuevo: miley se suma block_size: 27013
# word nuevo: tutta se suma block_size: 27243
# word nuevo: fatta se suma block_size: 27473
# word nuevo: billi se suma block_size: 27703
# word nuevo: eilish se suma block_size: 27934
# word nuevo: sei se suma block_size: 28162
# word nuevo: vicina se suma block_size: 28393
# word nuevo: polemica se suma block_size: 28626
# word nuevo: oh se suma block_size: 28853
# word nuevo: lontana se suma block_size: 29085
# word nuevo: l se suma block_size: 29311
# word nuevo: america se suma block_size: 29543
# word nuevo: fai se suma block_size: 29771
# word nuevo: scorrer se suma block_size: 30003
# word nuevo: sangu se suma block_size: 30233
# word nuevo: nella se suma block_size: 30463
# word nuevo: mia se suma block_size: 30691
# word nuevo: vena se suma block_size: 30920
# word nuevo: poetica se suma block_size: 31152
# word nuevo: lucio se suma block_size: 31382
# word nuevo: dalla se suma block_size: 31612
# word nuevo: part se suma block_size: 31841
# word nuevo: mano se suma block_size: 32070
# word nuevo: fa se suma block_size: 32297
# word nuevo: dedica se suma block_size: 32528
# word nuevo: penso se suma block_size: 32758
# word nuevo: le se suma block_size: 32985
# word nuevo: escono se suma block_size: 33216
# word nuevo: metrica se suma block_size: 33448
# word nuevo: facil se suma block_size: 33678
# word nuevo: trovarl se suma block_size: 33910
# word nuevo: erba se suma block_size: 34139
# word nuevo: su se suma block_size: 34366
# word nuevo: telegram se suma block_size: 34599
# word nuevo: bugi se suma block_size: 34828
# word nuevo: sono se suma block_size: 35057
# word nuevo: vendita se suma block_size: 35289
# word nuevo: tu se suma block_size: 35516
# word nuevo: siero se suma block_size: 35746
# word nuevo: della se suma block_size: 35976
# word nuevo: verità se suma block_size: 36223
# word nuevo: del se suma block_size: 36451
# word nuevo: pentot se suma block_size: 36682
# word nuevo: sensazion se suma block_size: 36916
# word nuevo: volt se suma block_size: 37145
# word nuevo: stiamo se suma block_size: 37376
# word nuevo: bene se suma block_size: 37605
# word nuevo: spiagg se suma block_size: 37836
# word nuevo: mare se suma block_size: 38065
# word nuevo: barch se suma block_size: 38295
# word nuevo: orizzont se suma block_size: 38528
# word nuevo: ci se suma block_size: 38755
# word nuevo: perdiamo se suma block_size: 38988
# word nuevo: tra se suma block_size: 39216
# word nuevo: ond se suma block_size: 39444
# word nuevo: male se suma block_size: 39673
# word nuevo: si se suma block_size: 39900
# word nuevo: confond se suma block_size: 40132
# word nuevo: nostr se suma block_size: 40362
# word nuevo: ombr se suma block_size: 40591
# word nuevo: feat se suma block_size: 40820
# word nuevo: j se suma block_size: 41046
# Writing block 5 to disk (block size: 41046 bytes)
# Block 5 written to disk as ./blocks/block_5.txt
# word nuevo: ax se suma block_size: 227
# word nuevo: boomdabash se suma block_size: 462
# word nuevo: rocco se suma block_size: 692
# word nuevo: hunt se suma block_size: 921
# word nuevo: libertà se suma block_size: 1169
# word nuevo: musica se suma block_size: 1400
# word nuevo: italiana se suma block_size: 1633
# word nuevo: 2020 se suma block_size: 1862
# word nuevo: playlist se suma block_size: 2095
# word nuevo: pop se suma block_size: 2323
# word nuevo: hip se suma block_size: 2551
# word nuevo: hop se suma block_size: 2779
# word nuevo: canzoni se suma block_size: 3011
# word nuevo: italian se suma block_size: 3243
# word nuevo: r se suma block_size: 3469
# word nuevo: b se suma block_size: 3695
# ...
# word nuevo: riot se suma block_size: 15149
# word nuevo: yeah se suma block_size: 15378
# word nuevo: good se suma block_size: 15607
# word nuevo: great se suma block_size: 15837
# word nuevo: one se suma block_size: 16065
# word nuevo: outrag se suma block_size: 16296
# word nuevo: costum se suma block_size: 16527
# word nuevo: brian se suma block_size: 16757
# word nuevo: may se suma block_size: 16985
# word nuevo: outta se suma block_size: 17215
# word nuevo: sight se suma block_size: 17445
# word nuevo: man se suma block_size: 17673
# word nuevo: mani se suma block_size: 17902
# word nuevo: true se suma block_size: 18131
# word nuevo: woah se suma block_size: 18360
# word nuevo: funni se suma block_size: 18590
# word nuevo: alway se suma block_size: 18820
# word nuevo: groupi se suma block_size: 19051
# word nuevo: oh se suma block_size: 19278
# word nuevo: could se suma block_size: 19508
# word nuevo: less se suma block_size: 19737
# word nuevo: shit se suma block_size: 19966
# word nuevo: remast se suma block_size: 20197
# word nuevo: 2011 se suma block_size: 20426
# word nuevo: queen se suma block_size: 20656
# word nuevo: jazz se suma block_size: 20885
# word nuevo: discografia se suma block_size: 21121
# word nuevo: completa se suma block_size: 21354
# word nuevo: album se suma block_size: 21584
# Block 10 written to disk as ./blocks/block_10.txt
# word nuevo: tight se suma block_size: 21814
# word nuevo: fli se suma block_size: 22042
# word nuevo: lift se suma block_size: 22299
# word nuevo: shift se suma block_size: 22529
# word nuevo: higher se suma block_size: 22760
# word nuevo: ceil se suma block_size: 22989
# word nuevo: ooh se suma block_size: 23217
# word nuevo: wee se suma block_size: 23445
# word nuevo: ultim se suma block_size: 23675
# word nuevo: feel se suma block_size: 23904
# word nuevo: gift se suma block_size: 24133
# word nuevo: sugar se suma block_size: 24363
# word nuevo: suga se suma block_size: 24620
# word nuevo: know se suma block_size: 24849
# word nuevo: leather se suma block_size: 25081
# word nuevo: ride se suma block_size: 25310
# word nuevo: fling se suma block_size: 25540
# word nuevo: rawhid se suma block_size: 25771
# word nuevo: watch se suma block_size: 26001
# word nuevo: screen se suma block_size: 26232
# word nuevo: gurl se suma block_size: 26489
# word nuevo: keep se suma block_size: 26718
# word nuevo: sweet se suma block_size: 26948
# word nuevo: hunnybun se suma block_size: 27181
# word nuevo: money se suma block_size: 27411
# word nuevo: gone se suma block_size: 27640
# word nuevo: top se suma block_size: 27896
# word nuevo: lie se suma block_size: 28124
# word nuevo: love se suma block_size: 28353
# word nuevo: blow se suma block_size: 28582
# word nuevo: lil se suma block_size: 28810
# word nuevo: yo se suma block_size: 29037
# word nuevo: littl se suma block_size: 29267
# word nuevo: chulo se suma block_size: 29497
# word nuevo: everi se suma block_size: 29727
# word nuevo: kick se suma block_size: 29984
# word nuevo: groovi se suma block_size: 30215
# word nuevo: treat se suma block_size: 30445
# word nuevo: like se suma block_size: 30674
# word nuevo: sticki se suma block_size: 30905
# word nuevo: ickey se suma block_size: 31135
# word nuevo: oowi se suma block_size: 31364
# word nuevo: goowi se suma block_size: 31594
# word nuevo: fa se suma block_size: 31821
# word nuevo: real se suma block_size: 32050
# word nuevo: though se suma block_size: 32281
# word nuevo: worri se suma block_size: 32511
# word nuevo: thang se suma block_size: 32741
# word nuevo: caus se suma block_size: 32970
# word nuevo: hit se suma block_size: 33198
# word nuevo: lick se suma block_size: 33427
# word nuevo: fat se suma block_size: 33655
# word nuevo: sack se suma block_size: 33884
# word nuevo: superfli se suma block_size: 34117
# word nuevo: chick se suma block_size: 34347
# word nuevo: say se suma block_size: 34603
# word nuevo: playa se suma block_size: 34833
# word nuevo: doowop se suma block_size: 35064
# word nuevo: plane se suma block_size: 35294
# word nuevo: air se suma block_size: 35522
# word nuevo: full se suma block_size: 35779
# word nuevo: grown se suma block_size: 36009
# word nuevo: set se suma block_size: 36237
# word nuevo: wrong se suma block_size: 36467
# word nuevo: tone se suma block_size: 36696
# word nuevo: energi se suma block_size: 36955
# word nuevo: zone se suma block_size: 37184
# word nuevo: dove se suma block_size: 37413
# word nuevo: raven se suma block_size: 37643
# word nuevo: quick se suma block_size: 37873
# word nuevo: polit se suma block_size: 38103
# word nuevo: convers se suma block_size: 38335
# word nuevo: natur se suma block_size: 38565
# word nuevo: mood se suma block_size: 38794
# word nuevo: dude se suma block_size: 39023
# word nuevo: fool se suma block_size: 39252
# word nuevo: pool se suma block_size: 39481
# word nuevo: sexi se suma block_size: 39710
# word nuevo: cool se suma block_size: 39939
# word nuevo: mama se suma block_size: 40168
# word nuevo: blade se suma block_size: 40398
# word nuevo: berata se suma block_size: 40629
# word nuevo: rockin se suma block_size: 40860
# word nuevo: dolc se suma block_size: 41089
# Writing block 10 to disk (block size: 41089 bytes)
# Block 10 written to disk as ./blocks/block_10.txt
# word nuevo: gabbana se suma block_size: 232
# word nuevo: italian se suma block_size: 464
# word nuevo: highdrow se suma block_size: 697
# word nuevo: cubana se suma block_size: 928
# word nuevo: got se suma block_size: 1156
# word nuevo: lift se suma block_size: 1385
# word nuevo: shift se suma block_size: 1615
# word nuevo: higher se suma block_size: 1846
# word nuevo: ceil se suma block_size: 2075
# word nuevo: ooh se suma block_size: 2303
# word nuevo: wee se suma block_size: 2531
# word nuevo: ultim se suma block_size: 2761
# word nuevo: feel se suma block_size: 2990
# word nuevo: gift se suma block_size: 3219
# word nuevo: sugar se suma block_size: 3449
# word nuevo: get se suma block_size: 3677
# word nuevo: fli se suma block_size: 3905
# word nuevo: suga se suma block_size: 4134
# word nuevo: know se suma block_size: 4363
# word nuevo: leather se suma block_size: 4595
# word nuevo: ride se suma block_size: 4824
# word nuevo: fling se suma block_size: 5054
# word nuevo: rawhid se suma block_size: 5285
# word nuevo: watch se suma block_size: 5515
# word nuevo: screen se suma block_size: 5746
# word nuevo: high se suma block_size: 5975
# word nuevo: gurl se suma block_size: 6204
# word nuevo: keep se suma block_size: 6433
# word nuevo: sweet se suma block_size: 6663
# word nuevo: hunnybun se suma block_size: 6896
# word nuevo: money se suma block_size: 7126
# word nuevo: gone se suma block_size: 7355
# word nuevo: come se suma block_size: 7584
# word nuevo: fa se suma block_size: 7811
# word nuevo: real se suma block_size: 8040
# word nuevo: though se suma block_size: 8271
# word nuevo: like se suma block_size: 8500
# word nuevo: star se suma block_size: 8729
# word nuevo: azucar se suma block_size: 8960
# word nuevo: babi se suma block_size: 9189
# word nuevo: bash se suma block_size: 9418
# word nuevo: tha se suma block_size: 9646
# word nuevo: smokin se suma block_size: 9877
# word nuevo: nephew se suma block_size: 10108
# word nuevo: 90s se suma block_size: 10336
# word nuevo: 00s se suma block_size: 10564
# word nuevo: hip se suma block_size: 10792
# word nuevo: hop se suma block_size: 11020
# word nuevo: rnb se suma block_size: 11248
# word nuevo: r se suma block_size: 11474
# word nuevo: b se suma block_size: 11700
# word nuevo: pop se suma block_size: 11928
# Block 11 written to disk as ./blocks/block_11.txt
# word nuevo: na se suma block_size: 12183
# word nuevo: yeah se suma block_size: 12412
# word nuevo: act se suma block_size: 12640
# word nuevo: homi se suma block_size: 12925
# word nuevo: ho se suma block_size: 13152
# word nuevo: gon se suma block_size: 13380
# word nuevo: oh se suma block_size: 13607
# word nuevo: time se suma block_size: 13836
# word nuevo: fuck se suma block_size: 14093
# word nuevo: mine se suma block_size: 14322
# word nuevo: see se suma block_size: 14550
# word nuevo: girl se suma block_size: 14779
# word nuevo: good se suma block_size: 15008
# word nuevo: step se suma block_size: 15237
# word nuevo: back se suma block_size: 15466
# word nuevo: chit se suma block_size: 15695
# word nuevo: chat se suma block_size: 15924
# word nuevo: killin se suma block_size: 16155
# word nuevo: vibe se suma block_size: 16384
# word nuevo: woah se suma block_size: 16613
# word nuevo: ah se suma block_size: 16840
# word nuevo: much se suma block_size: 17097
# word nuevo: thing se suma block_size: 17327
# word nuevo: mmm se suma block_size: 17555
# word nuevo: dress se suma block_size: 17785
# word nuevo: finest se suma block_size: 18016
# word nuevo: pleas se suma block_size: 18246
# word nuevo: hold se suma block_size: 18475
# word nuevo: tongu se suma block_size: 18705
# word nuevo: say se suma block_size: 18933
# word nuevo: damn se suma block_size: 19162
# word nuevo: iphon se suma block_size: 19392
# word nuevo: camera se suma block_size: 19623
# word nuevo: flashin se suma block_size: 19855
# word nuevo: style se suma block_size: 20085
# word nuevo: crampin se suma block_size: 20317
# word nuevo: long se suma block_size: 20546
# word nuevo: passin se suma block_size: 20777
# word nuevo: wanna se suma block_size: 21007
# word nuevo: drink se suma block_size: 21237
# word nuevo: nah se suma block_size: 21465
# word nuevo: thank se suma block_size: 21695
# word nuevo: askin se suma block_size: 21925
# word nuevo: mean se suma block_size: 22154
# word nuevo: could se suma block_size: 22384
# word nuevo: throw se suma block_size: 22614
# word nuevo: shape se suma block_size: 22844
# word nuevo: togeth se suma block_size: 23075
# word nuevo: circl se suma block_size: 23305
# word nuevo: cruis se suma block_size: 23535
# word nuevo: life se suma block_size: 23764
# word nuevo: feelin se suma block_size: 23995
# word nuevo: track se suma block_size: 24225
# word nuevo: better se suma block_size: 24484
# word nuevo: fall se suma block_size: 24713
# word nuevo: uh se suma block_size: 24940
# word nuevo: caus se suma block_size: 25169
# word nuevo: look se suma block_size: 25398
# word nuevo: stack se suma block_size: 25628
# word nuevo: round se suma block_size: 25886
# word nuevo: want se suma block_size: 26143
# word nuevo: tell se suma block_size: 26372
# word nuevo: radio se suma block_size: 26602
# word nuevo: edit se suma block_size: 26831
# word nuevo: jax se suma block_size: 27059
# word nuevo: jone se suma block_size: 27288
# word nuevo: ballar se suma block_size: 27519
# word nuevo: post se suma block_size: 27776
# word nuevo: teen se suma block_size: 28005
# Block 11 written to disk as ./blocks/block_11.txt
# word nuevo: everybodi se suma block_size: 28239
# word nuevo: love se suma block_size: 28496
# word nuevo: em se suma block_size: 28751
# word nuevo: ask se suma block_size: 28979
# word nuevo: heart se suma block_size: 29209
# word nuevo: desir se suma block_size: 29439
# word nuevo: one se suma block_size: 29695
# word nuevo: lie se suma block_size: 29923
# word nuevo: catch se suma block_size: 30153
# word nuevo: everi se suma block_size: 30383
# word nuevo: close se suma block_size: 30641
# word nuevo: eye se suma block_size: 30869
# word nuevo: hear se suma block_size: 31098
# word nuevo: secret se suma block_size: 31329
# word nuevo: talkin se suma block_size: 31588
# word nuevo: sleep se suma block_size: 31818
# word nuevo: talk se suma block_size: 32047
# word nuevo: told se suma block_size: 32276
# word nuevo: worri se suma block_size: 32506
# word nuevo: bout se suma block_size: 32735
# word nuevo: guy se suma block_size: 32963
# word nuevo: left se suma block_size: 33192
# word nuevo: behind se suma block_size: 33423
# word nuevo: wipe se suma block_size: 33652
# word nuevo: lust se suma block_size: 33937
# word nuevo: hide se suma block_size: 34166
# word nuevo: realiz se suma block_size: 34397
# word nuevo: divid se suma block_size: 34627
# word nuevo: weeknd se suma block_size: 34858
# word nuevo: starboy se suma block_size: 35090
# word nuevo: urban se suma block_size: 35320
# word nuevo: contemporari se suma block_size: 35557
# Block 11 written to disk as ./blocks/block_11.txt
# word nuevo: yeih se suma block_size: 35898
# word nuevo: voz se suma block_size: 36126
# word nuevo: favorit se suma block_size: 36358
# word nuevo: baby se suma block_size: 36587
# word nuevo: hol se suma block_size: 36815
# word nuevo: tal se suma block_size: 37043
# word nuevo: com se suma block_size: 37271
# word nuevo: quis se suma block_size: 37500
# word nuevo: molestart se suma block_size: 37734
# word nuevo: llamart se suma block_size: 37966
# word nuevo: se se suma block_size: 38193
# word nuevo: quizas se suma block_size: 38424
# word nuevo: esper se suma block_size: 38654
# word nuevo: confesart se suma block_size: 38888
# word nuevo: muer se suma block_size: 39117
# word nuevo: besart se suma block_size: 39348
# word nuevo: loc se suma block_size: 39576
# word nuevo: pued se suma block_size: 39805
# word nuevo: neg se suma block_size: 40033
# word nuevo: mir se suma block_size: 40261
# word nuevo: reaccion se suma block_size: 40494
# word nuevo: cambi se suma block_size: 40724
# word nuevo: pens se suma block_size: 40953
# word nuevo: desahog se suma block_size: 41185
# Writing block 11 to disk (block size: 41185 bytes)
# Block 11 written to disk as ./blocks/block_11.txt
# word nuevo: vay se suma block_size: 228
# word nuevo: cambi se suma block_size: 458
# word nuevo: enamor se suma block_size: 689
# word nuevo: tant se suma block_size: 918
# word nuevo: corazon se suma block_size: 1150
# word nuevo: qued se suma block_size: 1379
# word nuevo: pud se suma block_size: 1607
# word nuevo: evit se suma block_size: 1836
# word nuevo: intent se suma block_size: 2067
# word nuevo: yeih se suma block_size: 2296
# word nuevo: oh se suma block_size: 2523
# word nuevo: ah se suma block_size: 2750
# word nuevo: se se suma block_size: 2977
# word nuevo: cuest se suma block_size: 3207
# word nuevo: confi se suma block_size: 3437
# word nuevo: culp se suma block_size: 3666
# word nuevo: pas se suma block_size: 3894
# word nuevo: quier se suma block_size: 4124
# word nuevo: volv se suma block_size: 4353
# word nuevo: empez se suma block_size: 4583
# word nuevo: llor se suma block_size: 4812
# word nuevo: pens se suma block_size: 5041
# word nuevo: igual se suma block_size: 5271
# word nuevo: perd se suma block_size: 5500
# word nuevo: tiemp se suma block_size: 5730
# word nuevo: si se suma block_size: 5957
# word nuevo: vas se suma block_size: 6185
# word nuevo: ignor se suma block_size: 6415
# word nuevo: decirt se suma block_size: 6646
# word nuevo: sient se suma block_size: 6876
# word nuevo: voy se suma block_size: 7104
# word nuevo: call se suma block_size: 7333
# word nuevo: permit se suma block_size: 7564
# word nuevo: contig se suma block_size: 7795
# word nuevo: yeah se suma block_size: 8024
# word nuevo: acept se suma block_size: 8254
# word nuevo: trat se suma block_size: 8483
# word nuevo: pensart se suma block_size: 8715
# word nuevo: pued se suma block_size: 8944
# word nuevo: imagin se suma block_size: 9175
# word nuevo: aqu se suma block_size: 9403
# word nuevo: quis se suma block_size: 9632
# word nuevo: dig se suma block_size: 9860
# word nuevo: hac se suma block_size: 10088
# word nuevo: siempr se suma block_size: 10319
# word nuevo: extrañ se suma block_size: 10566
# word nuevo: convert se suma block_size: 10798
# word nuevo: vi se suma block_size: 11025
# word nuevo: camb se suma block_size: 11254
# word nuevo: nieg se suma block_size: 11483
# word nuevo: cieg se suma block_size: 11712
# word nuevo: olvidart se suma block_size: 11945
# word nuevo: nah se suma block_size: 12173
# word nuevo: voz se suma block_size: 12401
# word nuevo: favorit se suma block_size: 12633
# word nuevo: baby se suma block_size: 12862
# word nuevo: jay se suma block_size: 13090
# word nuevo: wheel se suma block_size: 13320
# word nuevo: platon se suma block_size: 13551
# word nuevo: latin se suma block_size: 13781
# word nuevo: pop se suma block_size: 14009
# word nuevo: rising se suma block_size: 14240
# Block 12 written to disk as ./blocks/block_12.txt
# {0: './blocks/block_0.txt',
#  1: './blocks/block_1.txt',
#  2: './blocks/block_2.txt',
#  4: './blocks/block_4.txt',
#  6: './blocks/block_6.txt',
#  7: './blocks/block_7.txt',
#  8: './blocks/block_8.txt',
#  9: './blocks/block_9.txt',
#  10: './blocks/block_10.txt',
#  11: './blocks/block_11.txt',
#  12: './blocks/block_12.txt'}
